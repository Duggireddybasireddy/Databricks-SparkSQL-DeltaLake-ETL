# %%
# To remove the files or folder from specified path
dbutils.fs.rm("dbfs:/FileStore/tables", recurse= True)
# Out:
# Out[3]: True

# %%
# %fs is same as dbutils.fs
# ls is for list of files
# %fs ls 'dbfs:/FileStore/tables'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/data/</td><td>data/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/metadata/</td><td>metadata/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/project/</td><td>project/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/transformation/</td><td>transformation/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# mkdirs for creating a new directory or folder
# %fs mkdirs "dbfs:/FileStore/tables/nyctaxidata/landing/greendata/green_tripdata/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res4: Boolean = true
# </div>

# %%
# %fs mkdirs "dbfs:/FileStore/tables/nyctaxidata/landing/yellowdata/yellow_tripdata/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res5: Boolean = true
# </div>

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/ratecodes/")
# Out:
# Out[4]: True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/paymenttypes/")
# Out:
# Out[5]: True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/taxizones/")
# Out:
# Out[6]: True

# %%
# %fs ls '/FileStore/tables/nyctaxidata/landing/greendata/green_tripdata/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls "/FileStore/tables/nyctaxidata/landing/yellowdata/yellow_tripdata/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls "/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/paymenttypes/</td><td>paymenttypes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/ratecodes/</td><td>ratecodes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/taxizones/</td><td>taxizones/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/paymenttypes/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/paymenttypes/PaymentTypes.json</td><td>PaymentTypes.json</td><td>275</td><td>1763555856000</td></tr></tbody></table></div>

# %%
# %fs ls "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/ratecodes/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/ratecodes/RateCodes.csv</td><td>RateCodes.csv</td><td>135</td><td>1763555869000</td></tr></tbody></table></div>

# %%
# %fs ls "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/taxizones/"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/taxizones/TaxiZones.csv</td><td>TaxiZones.csv</td><td>12320</td><td>1763555882000</td></tr></tbody></table></div>

# %%
# head shows the data existing in the specified directory or file
# %fs head "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/paymenttypes/PaymentTypes.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;PaymentTypeID&quot;:1,&quot;PaymentType&quot;:&quot;Credit Card&quot;}
# {&quot;PaymentTypeID&quot;:2,&quot;PaymentType&quot;:&quot;Cash&quot;}
# {&quot;PaymentTypeID&quot;:3,&quot;PaymentType&quot;:&quot;No Charge&quot;}
# {&quot;PaymentTypeID&quot;:4,&quot;PaymentType&quot;:&quot;Dispute&quot;}
# {&quot;PaymentTypeID&quot;:5,&quot;PaymentType&quot;:&quot;Unknown&quot;}
# {&quot;PaymentTypeID&quot;:6,&quot;PaymentType&quot;:&quot;Voided Trip&quot;}
# </div>

# %%
# %fs head "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/ratecodes/RateCodes.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">﻿RateCodeID,RateCode,IsApproved
# 1,Standard Rate,Yes
# 2,JFK,Yes
# 3,Newark,Yes
# 4,Westchester,Yes
# 5,Negotiated fare,
# 6,GroupRide,Yes
# </div>

# %%
# %fs head "dbfs:/FileStore/tables/nyctaxidata/landing/yellow_green_commondata/taxizones/TaxiZones.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&quot;LocationID&quot;,&quot;Borough&quot;,&quot;Zone&quot;,&quot;service_zone&quot;
# 1,&quot;EWR&quot;,&quot;Newark Airport&quot;,&quot;EWR&quot;
# 2,&quot;Queens&quot;,&quot;Jamaica Bay&quot;,&quot;Boro Zone&quot;
# 3,&quot;Bronx&quot;,&quot;Allerton/Pelham Gardens&quot;,&quot;Boro Zone&quot;
# 4,&quot;Manhattan&quot;,&quot;Alphabet City&quot;,&quot;Yellow Zone&quot;
# 5,&quot;Staten Island&quot;,&quot;Arden Heights&quot;,&quot;Boro Zone&quot;
# 6,&quot;Staten Island&quot;,&quot;Arrochar/Fort Wadsworth&quot;,&quot;Boro Zone&quot;
# 7,&quot;Queens&quot;,&quot;Astoria&quot;,&quot;Boro Zone&quot;
# ...

# %%
# %fs head "dbfs:/FileStore/tables/nyctaxidata/landing/greendata/green_tripdata/green_tripdata_2019_01.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# VendorID,lpep_pickup_datetime,lpep_dropoff_datetime,store_and_fwd_flag,RatecodeID,PULocationID,DOLocationID,passenger_count,trip_distance,fare_amount,extra,mta_tax,tip_amount,tolls_amount,ehail_fee,improvement_surcharge,total_amount,payment_type,trip_type,congestion_surcharge
# 2,2018-12-21 15:17:29,2018-12-21 15:18:57,N,1,264,264,5,.00,3,0.5,0.5,0,0,,0.3,4.3,2,1,
# 2,2019-01-01 00:10:16,2019-01-01 00:16:32,N,1,97,49,2,.86,6,0.5,0.5,0,0,,0.3,7.3,2,1,
# 2,2019-01-01 00:27:11,2019-01-01 00:31:38,N,1,49,189,2,.66,4.5,0.5,0.5,0,0,,0.3,5.8,1,1,
# ...

# %%
# %fs head "dbfs:/FileStore/tables/nyctaxidata/landing/yellowdata/yellow_tripdata/yellow_tripdata_2019_02.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount,congestion_surcharge
# 1,2019-02-01 00:59:04,2019-02-01 01:07:27,1,2.10,1,N,48,234,1,9,0.5,0.5,2,0,0.3,12.3,0
# 1,2019-02-01 00:33:09,2019-02-01 01:03:58,1,9.80,1,N,230,93,2,32,0.5,0.5,0,0,0.3,33.3,0
# 1,2019-02-01 00:09:03,2019-02-01 00:09:16,1,.00,1,N,145,145,2,2.5,0.5,0.5,0,0,0.3,3.8,0
# ...

# %%
dbutils.fs.help("rm")
# Out:
# <div class = "ansiout">/**<br /> * Removes a file or directory.<br /> * <br /> * Example: rm("/mnt/my-folder/", true)<br /> * <br /> * @param dir FileSystem URI for a single file or a directory<br /> * @param recurse if true, all files and directories will be recursively deleted<br /> * @return true if the file or directory was present and is now deleted<br /> */<br /><b>rm(dir: java.lang.String, recurse: boolean = false): boolean</b></div><br />
